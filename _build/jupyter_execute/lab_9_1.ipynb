# %% [markdown]
# # Lab 9
#
# _[General notebook information](https://computing-in-context.afeld.me/notebooks.html)_
#
# The goal here is to practice [joining datasets through pandas](https://pandas.pydata.org/docs/user_guide/merging.html#merge). Hint: The instructions here are intentionally incomplete.

# %% [markdown]
# ## Step 1
#
# Find an NYC dataset with a borough column.
#
# - Use [Scout](https://scout.tsdataclinic.com/explore/NYC) to filter by column name.
# - Don't spend too long on this step.
# - [Keep the dataset small](https://python-public-policy.afeld.me/en/columbia/assignments.html#reducing-data-size) (under 500,000-ish rows) to make it easier to work with.

# %% [markdown]
# **What's the URL of your dataset?**

# %% [markdown]
# YOUR RESPONSE HERE

# %% [markdown]
# ## Step 2
#
# Save and load the dataset.

# %%
import pandas as pd
project = pd.read_csv("2022_Annual_Sustainability_Project_Grant_20241031.csv")
project
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 project = pd.read_csv("2022_Annual_Sustainability_Project_Grant_20241031.csv")
#       3 project
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2022_Annual_Sustainability_Project_Grant_20241031.csv'

# %% [markdown]
# ## Step 3
#
# Download and load the [Population by Borough](https://data.cityofnewyork.us/City-Government/New-York-City-Population-by-Borough-1950-2040/xywu-7bv9) dataset.

# %%
population = pd.read_csv("New_York_City_Population_by_Borough__1950_-_2040_20241031.csv")
population
# Out:
#           Age Group           Borough     1950  \
# 0  Total Population         NYC Total  7891957
# 1  Total Population             Bronx  1451277
# 2  Total Population          Brooklyn  2738175
# 3  Total Population         Manhattan  1960101
# 4  Total Population            Queens  1550849
# 5  Total Population     Staten Island   191555
#
#    1950 - Boro share of NYC total     1960  1960 - Boro share of NYC total  \
# 0                          100.00  7781984                          100.00
# 1                           18.39  1424815                           18.31
# 2                           34.70  2627319                           33.76
# 3                           24.84  1698281                           21.82
# 4                           19.65  1809578                           23.25
# 5                            2.43   221991                            2.85
#
#       1970  1970 - Boro share of NYC total     1980  \
# 0  7894862                          100.00  7071639
# 1  1471701                           18.64  1168972
# 2  2602012                           32.96  2230936
# 3  1539233                           19.50  1428285
# 4  1986473                           25.16  1891325
# 5   295443                            3.74   352121
#
#    1980 - Boro share of NYC total  ...     2000  \
# 0                          100.00  ...  8008278
# 1                           16.53  ...  1332650
# 2                           31.55  ...  2465326
# 3                           20.20  ...  1537195
# 4                           26.75  ...  2229379
# 5                            4.98  ...   443728
#
#    2000 - Boro share of NYC total     2010  2010 - Boro share of NYC total  \
# 0                          100.00  8242624                          100.00
# 1                           16.64  1385108                           16.80
# 2                           30.78  2552911                           30.97
# 3                           19.20  1585873                           19.24
# 4                           27.84  2250002                           27.30
# 5                            5.54   468730                            5.69
#
#       2020  2020 - Boro share of NYC total     2030  \
# 0  8550971                          100.00  8821027
# 1  1446788                           16.92  1518998
# 2  2648452                           30.97  2754009
# 3  1638281                           19.16  1676720
# 4  2330295                           27.25  2373551
# 5   487155                            5.70   497749
#
#    2030 - Boro share of NYC total     2040  2040 - Boro share of NYC total
# 0                          100.00  9025145                          100.00
# 1                           17.22  1579245                           17.50
# 2                           31.22  2840525                           31.47
# 3                           19.01  1691617                           18.74
# 4                           26.91  2412649                           26.73
# 5                            5.64   501109                            5.55
#
# [6 rows x 22 columns]

# %% [markdown]
# ## Step 4
#
# Use [`merge()`](https://pandas.pydata.org/docs/user_guide/merging.html#merge) to combine the two, and output the resulting table.

# %%
population["Borough"] = population["Borough"].astype(str).str.strip()
project["Borough"] = project["Borough"].astype(str).str.strip()

merged = pd.merge(population,project,on = "Borough", how = "inner")
merged
# Out:
#             Age Group        Borough     1950  1950 - Boro share of NYC total  \
# 0    Total Population          Bronx  1451277                           18.39
# 1    Total Population          Bronx  1451277                           18.39
# 2    Total Population          Bronx  1451277                           18.39
# 3    Total Population          Bronx  1451277                           18.39
# 4    Total Population          Bronx  1451277                           18.39
# ..                ...            ...      ...                             ...
# 112  Total Population         Queens  1550849                           19.65
# 113  Total Population         Queens  1550849                           19.65
# 114  Total Population         Queens  1550849                           19.65
# 115  Total Population  Staten Island   191555                            2.43
# 116  Total Population  Staten Island   191555                            2.43
#
#         1960  1960 - Boro share of NYC total     1970  \
# 0    1424815                           18.31  1471701
# 1    1424815                           18.31  1471701
# 2    1424815                           18.31  1471701
# 3    1424815                           18.31  1471701
# 4    1424815                           18.31  1471701
# ..       ...                             ...      ...
# 112  1809578                           23.25  1986473
# 113  1809578                           23.25  1986473
# 114  1809578                           23.25  1986473
# 115   221991                            2.85   295443
# 116   221991                            2.85   295443
#
#      1970 - Boro share of NYC total     1980  1980 - Boro share of NYC total  \
# 0                             18.64  1168972                           16.53
# 1                             18.64  1168972                           16.53
# 2                             18.64  1168972                           16.53
# 3                             18.64  1168972                           16.53
# 4                             18.64  1168972                           16.53
# ..                              ...      ...                             ...
# 112                           25.16  1891325                           26.75
# 113                           25.16  1891325                           26.75
# 114                           25.16  1891325                           26.75
# 115                            3.74   352121                            4.98
# 116                            3.74   352121                            4.98
#
#      ...  2010 - Boro share of NYC total     2020  \
# 0    ...                           16.80  1446788
# 1    ...                           16.80  1446788
# 2    ...                           16.80  1446788
# 3    ...                           16.80  1446788
# 4    ...                           16.80  1446788
# ..   ...                             ...      ...
# 112  ...                           27.30  2330295
# 113  ...                           27.30  2330295
# 114  ...                           27.30  2330295
# 115  ...                            5.69   487155
# 116  ...                            5.69   487155
#
#      2020 - Boro share of NYC total     2030  2030 - Boro share of NYC total  \
# 0                             16.92  1518998                           17.22
# 1                             16.92  1518998                           17.22
# 2                             16.92  1518998                           17.22
# 3                             16.92  1518998                           17.22
# 4                             16.92  1518998                           17.22
# ..                              ...      ...                             ...
# 112                           27.25  2373551                           26.91
# 113                           27.25  2373551                           26.91
# 114                           27.25  2373551                           26.91
# 115                            5.70   497749                            5.64
# 116                            5.70   497749                            5.64
#
#         2040  2040 - Boro share of NYC total  \
# 0    1579245                           17.50
# 1    1579245                           17.50
# 2    1579245                           17.50
# 3    1579245                           17.50
# 4    1579245                           17.50
# ..       ...                             ...
# 112  2412649                           26.73
# 113  2412649                           26.73
# 114  2412649                           26.73
# 115   501109                            5.55
# 116   501109                            5.55
#
#                                      School Name     DBN  \
# 0                                 Accion Academy  12X341
# 1    Arturo A. Schomburg Satellite Academy Bronx  12X446
# 2                       Astor Collegiate Academy  11X299
# 3                 Bedford Park Elementary School  10X077
# 4       Bronx Center for Science and Mathematics  09X260
# ..                                           ...     ...
# 112                                    P.S. Q233  75Q233
# 113                                    P.S. Q811  75Q811
# 114                              Pioneer Academy  24Q307
# 115                    P.S. 013 M. L. Lindemeyer  31R013
# 116                          P.S. 045 John Tyler  31R045
#
#                    Grant Category
# 0    Gardening & Outdoor Learning
# 1             Green Team Supports
# 2    Gardening & Outdoor Learning
# 3    Gardening & Outdoor Learning
# 4    Gardening & Outdoor Learning
# ..                            ...
# 112  Gardening & Outdoor Learning
# 113  Gardening & Outdoor Learning
# 114  Gardening & Outdoor Learning
# 115  Gardening & Outdoor Learning
# 116           Green Team Supports
#
# [117 rows x 25 columns]

# %% [markdown]
# ## Step 5
#
# Using the two datasets above, use pandas to produce an aggregate per-capita statistic by borough.
#
# The dataset you chose before may not work for this. That's fine, pick another.
#
# ### Hint
#
# You're creating a "number of [thing] per capita by borough" table.
#
# 1. Do a [`groupby()`](https://pandas.pydata.org/docs/user_guide/groupby.html) on the original dataset.
# 1. Join with the populations by borough.
# 1. Compute the per-capita values as a new column.

# %%
project_counts = project.groupby('Borough').size()
project_counts
# Out:
# Borough
# Bronx            40
# Brooklyn         42
# Manhattan        21
# Queens           12
# Staten Island     2
# dtype: int64

# %%
project_counts_df = project_counts.to_frame(name = "Project Count")
project_counts_df
# Out:
#                Project Count
# Borough
# Bronx                     40
# Brooklyn                  42
# Manhattan                 21
# Queens                    12
# Staten Island              2

# %%
project_counts_df = project_counts.reset_index(name = "Project Count")
project_counts_df
# Out:
#          Borough  Project Count
# 0          Bronx             40
# 1       Brooklyn             42
# 2      Manhattan             21
# 3         Queens             12
# 4  Staten Island              2

# %%
merged_data = pd.merge(project_counts_df, population[['Borough', '2020']], on='Borough', how='inner')
merged_data['Granted Projects per Capita'] = merged_data['Project Count'] / merged_data['2020']
merged_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 merged_data = pd.merge(project_counts_df, population[['Borough', '2020']], on='Borough', how='inner')
#       2 merged_data['Granted Projects per Capita'] = merged_data['Project Count'] / merged_data['2020']
#       3 merged_data
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Step 6
#
# Submit via Gradescope.
